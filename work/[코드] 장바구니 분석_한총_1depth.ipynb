# %% [markdown]
# # 한총 장바구니 분석

# %%
#데이터셋 가져오기
#order 컬럼명 바꾸기 - 숫자로 되어 있는 부분에 Order (purchase event) 입력
import pandas as pd
#카테고리 전처리
import re
# 장바구니 분석
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import apriori, association_rules
import datetime as dt
import os

# %% [markdown]
# ### 0. 경로 설정

# %%
input_path = 'C:/GMG_R&D/3. 장바구니 분석/1. 한총'  #input("작업 파일 경로를 입력하세요")
os.chdir(input_path)
path=os.getcwd()
print(path)

#폴더 생성
x = dt.datetime.now()
file_name=f'분석결과_1depth_{x.year}{x.month}{x.day}'

if not os.path.exists(file_name):
    os.mkdir(file_name)
# Out:
# C:\GMG_R&D\3. 장바구니 분석\1. 한총

# %% [markdown]
# ### 1. 한총 데이터 로드

# %%
df= pd.read_clipboard(sep='\t')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50001 entries, Model Code (v41) to EF-RS906CNEGKR,EP-TA800XWKGKR
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   2020년            50001 non-null  int64
#  1   2021년            50001 non-null  int64
#  2   2022.01~2022.11  50001 non-null  int64
# dtypes: int64(3)
# memory usage: 1.5+ MB

# %%
df=df[1:]
df=df.reset_index().rename(columns={"index": "Model Code (v41)"})
df
# Out:
#                                         Model Code (v41)  2020년  2021년  \
# 0                                         EP-DG930MBKGKR   9746   6236
# 1                                             AA-BC7AU5B   9365      0
# 2                                         SM-R175NZWAKOO   4961    344
# 3                                         SM-N986NZNEKOO   4950    172
# 4                                         SM-R175NZBAKOO   4906    127
# ...                                                  ...    ...    ...
# 49995       EJ-P5450SBEGKR,GP-TTT870KDATK,GP-TTT870KDATK      0      0
# 49996  1FF10014,1FF10014,1FF10014,SAM20220221001,SAM2...      0      0
# 49997                               V00073,V00225,V00235      0      0
# 49998                                 21,405,702,145,135      0      0
# 49999                      EF-RS906CNEGKR,EP-TA800XWKGKR      0      0
#
#        2022.01~2022.11
# 0                 3665
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 49995                1
# 49996                1
# 49997                1
# 49998                1
# 49999                1
#
# [50000 rows x 4 columns]

# %%
df['Order (purchase event)']=df.iloc[:,1:4].sum(axis=1)
df
# Out:
#                                         Model Code (v41)  2020년  2021년  \
# 0                                         EP-DG930MBKGKR   9746   6236
# 1                                             AA-BC7AU5B   9365      0
# 2                                         SM-R175NZWAKOO   4961    344
# 3                                         SM-N986NZNEKOO   4950    172
# 4                                         SM-R175NZBAKOO   4906    127
# ...                                                  ...    ...    ...
# 49995       EJ-P5450SBEGKR,GP-TTT870KDATK,GP-TTT870KDATK      0      0
# 49996  1FF10014,1FF10014,1FF10014,SAM20220221001,SAM2...      0      0
# 49997                               V00073,V00225,V00235      0      0
# 49998                                 21,405,702,145,135      0      0
# 49999                      EF-RS906CNEGKR,EP-TA800XWKGKR      0      0
#
#        2022.01~2022.11  Order (purchase event)
# 0                 3665                   19647
# 1                    0                    9365
# 2                    0                    5305
# 3                    0                    5122
# 4                    0                    5033
# ...                ...                     ...
# 49995                1                       1
# 49996                1                       1
# 49997                1                       1
# 49998                1                       1
# 49999                1                       1
#
# [50000 rows x 5 columns]

# %%
for i in df.columns:
    if i=='Model Code (v41) (evar41)': 
        df=df.rename(columns={'Model Code (v41) (evar41)':'Model Code (v41)'})
df.columns

# %% [markdown]
# ### 2개 이상 구매자 비중

# %%
for percent_df in df.columns[1:]:
    print('****************************')
    print(percent_df )
    all=df[percent_df].sum()
    print('전체: ',all)
    print('2개이상: ',df[df[['Model Code (v41)',percent_df]]['Model Code (v41)'].str.contains(',')][percent_df].sum())
    
    print("제품 2개 구매 비중: ",round((df[df[['Model Code (v41)',percent_df]]['Model Code (v41)'].str.contains(',')][percent_df].sum()/all)*100,2))
# Out:
# ****************************
# 2020년
# 전체:  365380
# 2개이상:  63825
# 제품 2개 구매 비중:  17.47
# ****************************
# 2021년
# 전체:  738544
# 2개이상:  81837
# 제품 2개 구매 비중:  11.08
# ****************************
# 2022.01~2022.11
# 전체:  842619
# 2개이상:  58436
# 제품 2개 구매 비중:  6.94
# ****************************
# Order (purchase event)
# 전체:  1946543
# 2개이상:  204098
# 제품 2개 구매 비중:  10.49

# %%
df=df[df['Model Code (v41)'].str.contains(',')]
print('콤마 들어간거 행 수:',df.shape[0])
df=df.reset_index(drop=True)
# Out:
# 콤마 들어간거 행 수: 41987

# %%
#전체 SKU 하나의 리스트로
a = df['Model Code (v41)'].tolist()
b = ','.join(a) #리스트 문자열로
c = b.split(',') #문자열 개별 문자로 리스트화 
model = list(set(c)) #중복 제거

# %% [markdown]
# ### 2. 카테고리 파일 로드

# %%
#카테고리 가져오기
rex= pd.read_clipboard(sep='\t')
rex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category1D        7 non-null      object
#  1   Category1D_Value  7 non-null      object
# dtypes: object(2)
# memory usage: 240.0+ bytes

# %%
#전체 SKU 담을 딕셔너리
dic_category = {}

for m in model :
    flag = 1
    for i in range(len(rex)):
        r = re.compile(rex.Category1D_Value[i])
        if r.search(m):
            dic_category[m] = rex.Category1D[i]
            flag = 0
            continue
    if flag :
        dic_category[m] = '기타'

# %%
dic_category
# Out:
# {'': '기타',
#  'UN43N5020AFXKR': 'TV',
#  '184': '기타',
#  'SWA-W510/KR': '오디오',
#  'EF-DX900UBKGKR': '모바일',
#  'MR-100103': '기타',
#  'GP-TFN975KDATK': '모바일',
#  'D35192': '기타',
#  'EF-ZX700PWEGKR': '모바일',
#  '107': '기타',
#  'RA-F17NUU39': '주방가전',
#  'SM-F936NZEFKOO': '모바일',
#  'G91110006': '기타',
#  'AKGY100BTP': '오디오',
#  'P0000CYW': '기타',
#  'V00151': '기타',
#  'EF-XA336CBEGKR': '모바일',
#  'EF-KG980CLEGKR': '모바일',
#  'MUVC-1F7110237': '모바일',
#  'OTTA0010': '기타',
#  '767': '기타',
#  'dodram10494': '기타',
#  'SF241772': '기타',
#  'F0007': '기타',
#  'RA-F17DUU06': '주방가전',
#  'RA-R23DAAGLLD1': '주방가전',
#  'DW60B8155LWS': '주방가전',
#  'SKK-AKP': '생활가전',
#  'RA-D24DMM32': '주방가전',
#  'JBLGO3RED': '오디오',
#  'NT950XDC-XD71S': 'PC/주변기기',
#  '35548': '기타',
#  'SAM20220915031': '기타',
#  'WF24T8000KV': '생활가전',
#  'SAMEVENT20220105': '기타',
#  'ET-SFR86SYEGKR': '모바일',
#  'RA-F18DUU05': '주방가전',
#  'JBLLIVEFREE2TWSROS': '오디오',
#  'ET-SKR82MJEGKR': '모바일',
#  'HGFG0028': '기타',
#  'EF-EA536PWEGKR': '모바일',
#  'DW50R4055BBS': '주방가전',
#  'sf244748': '기타',
#  'AC100BS4DBC1SY': '생활가전',
#  'VR50T95936U': '생활가전',
#  'HGFG0024': '기타',
#  'NZ63B4026AK': '주방가전',
#  'SM-A336NZKTKOO': '모바일',
#  'SM-A102NZWAKOO': '모바일',
#  'SAM0020': '기타',
#  'EF-ZX800PBEGKR': '모바일',
#  'A0019': '기타',
#  'SK-P1000P': 'PC/주변기기',
#  'SM-T865NZADKOO': '모바일',
#  'NZ63B6507XNEL': '주방가전',
#  'GP-G975HIFGHKA': '모바일',
#  'ECOVERZERO2': '기타',
#  'RQ33T74A1AP': '주방가전',
#  'RA-K27DBB3D': '주방가전',
#  'AX060B510RPD': '생활가전',
#  'JBLQUANTUMDUOBLKAS': '오디오',
#  'RQ48T90Y3S9': '주방가전',
#  'GP-PWR840KKIOK': '모바일',
#  'NT950XEE-XD72S': 'PC/주변기기',
#  'JBLLIVEPRO2TWSSIL': '오디오',
#  'SM-T860NZBNKOO': '모바일',
#  'UN32N4020AFXKR': 'TV',
#  'SFN-M35VHNB': '생활가전',
#  'EF-DT730UBKGKR': '모바일',
#  'SM-P615NZAHKOO': '모바일',
#  'SM-R177NZWAKOO': '모바일',
#  'JBLFLIP6BLU': '오디오',
#  'ET-SHR89LSEGKR': '모바일',
#  'EF-VG988LBEGKR': '모바일',
#  'EF-RT500CJEGKR': '모바일',
#  'HW-Q990B/KR': '오디오',
#  'ET-SFR87LJEGKR': '모바일',
#  'EF-RN975CSEGKR': '모바일',
#  'NZ63N5300CK': '주방가전',
#  'SM-T870NZKAKOO': '모바일',
#  'SM-F711N1FWKOO': '모바일',
#  'SAM0025': '기타',
#  'INK-K610': 'PC/주변기기',
#  'RR40A7895AP': '주방가전',
#  'EF-MS906CWEGKR': '모바일',
#  'NZ60R3703PKB': '주방가전',
#  'EF-NN975PBEGKR': '모바일',
#  'KQ75QA60-W1': 'TV',
#  'DW50A4075U1S': '주방가전',
#  'RF60A91C38Y': '주방가전',
#  'MUVC-1F7110056': '모바일',
#  'EF-KG970CBEGKR': '모바일',
#  'EF-EA516PBEGKR': '모바일',
#  'NT950QDB-KD7MN': 'PC/주변기기',
#  'sf244897': '기타',
#  'VC33T3550LP': '생활가전',
#  'DW60A8375HC': '주방가전',
#  'KU75UA8000-W1': 'TV',
#  'RP22T31A1EG': '주방가전',
#  'EI-T5300BBEGKR': '모바일',
#  'EF-NN975PWEGKR': '모바일',
#  'SM-X800NIDFKOO': '모바일',
#  'VS20T9257SDCC': '생활가전',
#  'RR09BG014WW': '주방가전',
#  'LS43BM702UKXKR': 'PC/주변기기',
#  'SM-S908NDRFKOO': '모바일',
#  'RA-F17DBB04': '주방가전',
#  'NT935XDB-KC58B': 'PC/주변기기',
#  '233': '기타',
#  'f0048': '기타',
#  'AKGN400SIL': '오디오',
#  'KQ50QB80AFXKR': 'TV',
#  'DW-C00RKR10': '주방가전',
#  '921': '기타',
#  'NT950XDC-XD7MS': 'PC/주변기기',
#  'NPPS-9NT9500325': '기타',
#  'P10141015': '기타',
#  'KQ65QA80AFXKR': 'TV',
#  'DW60B8155SWUS': '주방가전',
#  'AF17AX771VFS': '생활가전',
#  'sf246785': '기타',
#  'KQ65QA70-W16': 'TV',
#  'AKGN400NVY': '오디오',
#  'MUVC-1F7110245': '모바일',
#  'HGFG0002': '기타',
#  'EF-ZG980CLEGKR': '모바일',
#  'SM-S908NZGRKOO': '모바일',
#  'SF245030': '기타',
#  'KQ65LSB01AFXKR': 'TV',
#  'CLT-K506S': 'PC/주변기기',
#  'P00000VJ': '기타',
#  'EE-MG950TBKGKR': '모바일',
#  'OTG21410013': '기타',
#  'RA-F18BBB02': '주방가전',
#  'SF240892': '기타',
#  'EJ-PT870BBEGKR': '모바일',
#  'EI-T7300BLEGKR': '모바일',
#  'GP-FPR180AMEBK': '모바일',
#  'RA-K27NBB01': '주방가전',
#  'SM-A315NZBAKOO': '모바일',
#  'CLT-Y506L': 'PC/주변기기',
#  'DF60T8300WG-AS': '생활가전',
#  'MLT-K200L': 'PC/주변기기',
#  '2112531': '기타',
#  'MUVC-1F7210345': '모바일',
#  'HGFG0034': '기타',
#  'SFN-N23DSCH': '생활가전',
#  'SM-X806NZAAKOO': '모바일',
#  '368': '기타',
#  'p2022060306': '기타',
#  'DV-RH1': '생활가전',
#  'V00059': '기타',
#  'SM-R910NZAAEVT': '모바일',
#  'V00134': '기타',
#  'RS84A5001CW': '주방가전',
#  'RA-F18PBB34': '주방가전',
#  'RA-B23DUU42': '주방가전',
#  'HB502KR': '기타',
#  'GP-FPR190HIBLK': '모바일',
#  '391': '기타',
#  'EF-NG996PVEGKR': '모바일',
#  'AW05A5171TZAS3': '생활가전',
#  'MD-LAMYSFBK3': '모바일',
#  'RA-F18DBB31': '주방가전',
#  'RA-F17DBB3B': '주방가전',
#  'SF255178': '기타',
#  'DV17T8520BV': '생활가전',
#  'SM-X806NIDAKOO': '모바일',
#  'RA-R23DAAGLLB5': '주방가전',
#  'GP-FPN981HIBBK': '모바일',
#  'AF-C3N1D': '생활가전',
#  'AX123A9970NDA1': '생활가전',
#  '2145137': '기타',
#  'NH-NY23226951': '기타',
#  'RQ48T94Y101': '주방가전',
#  'samevent20220103': '기타',
#  'SM-P615NZBNKOO': '모바일',
#  'WF25D20BVVL': '생활가전',
#  'RF85B95H2APN': '주방가전',
#  'GP-FPR177HICYK': '모바일',
#  'V00292': '기타',
#  'SM-A217NZRNKOO': '모바일',
#  'GF000073': '기타',
#  'SM-F711N4GFKOO': '모바일',
#  'NT950XDC-XD71B': 'PC/주변기기',
#  'PETHIGHSTANDPALM2': '기타',
#  'GP-TTR855KDATK': '모바일',
#  'CRS25T950008M': '주방가전',
#  'P2022010010': '기타',
#  'SM-R845NZSAKOO': '모바일',
#  'SM-G781NLVAKOO': '모바일',
#  'SM-P610NZAEKOO': '모바일',
#  'KQ43QB65AFXKR': 'TV',
#  'AF18AX978VZRT': '생활가전',
#  'DJ30B9500SE': '생활가전',
#  'KQ65LSA03-TK': 'TV',
#  'INK-M410': 'PC/주변기기',
#  'WF23T8000KV7': '생활가전',
#  'VCA-A': '생활가전',
#  'RZ24R5600AP': '주방가전',
#  'NT750XDA-XD72L': 'PC/주변기기',
#  'SM-R905NZAAKOO': '모바일',
#  'GP-FPR177AMFYK': '모바일',
#  'NZ63T8708XW': '주방가전',
#  'a0008': '기타',
#  'p2022010055': '기타',
#  'AX47T9560OSD': '생활가전',
#  'GP-TTX906KDATK': '모바일',
#  'SOUL19': '기타',
#  'SM-F936NZKFKOO': '모바일',
#  'RF71T5203SR': '주방가전',
#  'SF228872': '기타',
#  'AX40A5311WMD': '생활가전',
#  'LS32BM703UKXKR': 'PC/주변기기',
#  'DW60T7045FWS': '주방가전',
#  '1FA10105': '기타',
#  'AC032BS1PBH1SY': '생활가전',
#  'SM-R510NLVAPMT': '모바일',
#  'SM-S908NLBRKOO': '모바일',
#  'SOUL14': '기타',
#  'RF85B95E1APWWB': '주방가전',
#  'MD-S10EGOOLYC': '모바일',
#  'SF234259': '기타',
#  'sam0023': '기타',
#  'RA-F17DUU18': '주방가전',
#  'EF-BT970PAEGKR': '모바일',
#  'KQ75QB65AFXKR': 'TV',
#  '140': '기타',
#  'F400922': '기타',
#  'V00128': '기타',
#  'NT551XDA-KR35G': 'PC/주변기기',
#  'RS84T507116': '주방가전',
#  'SM-F711N1JWKOO': '모바일',
#  'P2022010036': '기타',
#  '1CA10211': '기타',
#  'ET-SXR87LBEGKR': '모바일',
#  'SM-R920NZKAKOO': '모바일',
#  'RA-F17BBB32': '주방가전',
#  'soul16': '기타',
#  'JBLQUANTUM800BLK': '오디오',
#  'EP-TA800XBKGKR': '모바일',
#  'P2022060327': '기타',
#  '617': '기타',
#  'p2022060324': '기타',
#  '265': '기타',
#  'RA-F18BBB39': '주방가전',
#  'SM-R910NZADKOO': '모바일',
#  'VMKS101': '기타',
#  'ET-SHR88SGEGKR': '모바일',
#  'RA-B23NBB44': '주방가전',
#  'SM-N981NZGEKOO': '모바일',
#  'VS15R8543S1': '생활가전',
#  'GP-FPR180AMDWK': '모바일',
#  'EF-NG996PJEGKR': '모바일',
#  'GP-TOT530HIBOK': '모바일',
#  'CRS25T850006': '주방가전',
#  'AF17A6478WZRZ': '생활가전',
#  'AX114T9360WWD': '생활가전',
#  'EF-MS906CNEGKR': '모바일',
#  'SF219806': '기타',
#  'AF17AX771VFRT': '생활가전',
#  'RA-M17BAA93': '주방가전',
#  '223': '기타',
#  'CLT-C404S': 'PC/주변기기',
#  'MLT-LL31W': 'PC/주변기기',
#  'f0004': '기타',
#  'sf252906': '기타',
#  'MG23T5018CE': '주방가전',
#  'GP-TOR190HOGUK': '모바일',
#  'JBLQUANTUM600BLK': '오디오',
#  'F922243722': '기타',
#  'CLT-K409S': 'PC/주변기기',
#  '364': '기타',
#  'SM-R177NZKAEVT': '모바일',
#  'RA-K31DMB05': '주방가전',
#  'AW05A5171GZAT2': '생활가전',
#  'SM-F711N4RFKOO': '모바일',
#  'EF-PN975TPEGKR': '모바일',
#  'CLT-Y503L': 'PC/주변기기',
#  'F0055': '기타',
#  'RA-F17DBB18': '주방가전',
#  'SM-R910NZAGK01': '모바일',
#  'AX106B850HSD': '생활가전',
#  'GP-FPG991TLBWW': '모바일',
#  'WV22N9670KP': '생활가전',
#  'KQ65QA70-W1': 'TV',
#  'RA-F17BBB04': '주방가전',
#  'EF-PS908TVEGKR': '모바일',
#  'V00223': '기타',
#  'p2022060322': '기타',
#  '420': '기타',
#  'JBLGO2GRY': '오디오',
#  'RA-K31PMM35': '주방가전',
#  'MG23T5018CC': '주방가전',
#  '383': '기타',
#  'V00288': '기타',
#  'a0014': '기타',
#  'SF241253': '기타',
#  'WF21T9500KW7T': '생활가전',
#  'AF-C3E1D': '생활가전',
#  'MHBSET': '기타',
#  'SM-A505NZWAKOO': '모바일',
#  'a0026': '기타',
#  'p2022010003': '기타',
#  'WA21A8376KV': '생활가전',
#  'V00265': '기타',
#  'VS15A680AFWD2': '생활가전',
#  'F4009181': '기타',
#  'GP-G973HIFGGKB': '모바일',
#  'RT32N503HS8': '주방가전',
#  'DV16T8740BWT': '생활가전',
#  'EF-QA235TBEGKR': '모바일',
#  'RQ33B71F1S9': '주방가전',
#  'SHILLASET': '기타',
#  'AW05A5171TZAS': '생활가전',
#  'SM-R510NLVAKOD': '모바일',
#  'JBLBAR20AIOBLKAS': '오디오',
#  'KQ55LST01AFXKR': 'TV',
#  'G12391130': '기타',
#  'KU85UB8000FXKR': 'TV',
#  'EF-PA536TBEGKR': '모바일',
#  'LT24H317HKDXKR': 'PC/주변기기',
#  'GF300029': '기타',
#  'sam20220221007': '기타',
#  '527': '기타',
#  'VS15A680AFW': '생활가전',
#  'EF-NG965PVEGKR': '모바일',
#  'V00215': '기타',
#  'ET-SFR86SNEGKR': '모바일',
#  'OTG23110068': '기타',
#  'SM-T725NZKNKOO': '모바일',
#  'RA-F18NBB39': '주방가전',
#  'CLT-M506L': 'PC/주변기기',
#  'F0020': '기타',
#  'SF223757': '기타',
#  'RA-F18BUU07': '주방가전',
#  'LH50BEAHLGFXKR': 'PC/주변기기',
#  'EF-ZS908CBEGKR': '모바일',
#  'AR16T9190HZS': '생활가전',
#  'V00084': '기타',
#  'AF-C3F1D': '생활가전',
#  'V00085': '기타',
#  'V00030': '기타',
#  'CFX-H1005D': '생활가전',
#  'RA-K16DUU38': '주방가전',
#  'SF234461': '기타',
#  'a0025': '기타',
#  'GP-FGN976HOAWK': '모바일',
#  'OTTA0003': '기타',
#  'SL-C565W/ASB': 'PC/주변기기',
#  'DV17A9740CS': '생활가전',
#  'CFX-H1705D': '생활가전',
#  'RA-K27DBB18': '주방가전',
#  'AP110BSPPBH6S': '생활가전',
#  'JBLT115TWSWHTAS': '오디오',
#  'SF219799': '기타',
#  'EF-QF721CTEGKR': '모바일',
#  'RF10B9935APG13': '주방가전',
#  'RA-R23DAA42': '주방가전',
#  '1CA10102': '기타',
#  'RA-B23DUU18': '주방가전',
#  '2145338': '기타',
#  'NT950XDC-XD5MS': 'PC/주변기기',
#  '494': '기타',
#  'AW05B5171TWAT1': '생활가전',
#  'WF23T8000KV7T': '생활가전',
#  'HW-S60A/KR': '오디오',
#  'SM-X706NZSFKOO': '모바일',
#  'CFX-J1005D': '생활가전',
#  'GP-PWR840KKKUK': '모바일',
#  'BL-H-MP': '기타',
#  'EF-MS901CNEGKR': '모바일',
#  'SF253915': '기타',
#  'EF-VN980LGEGKR': '모바일',
#  'VS20A957G33P': '생활가전',
#  'SM-F936NZKAKOO': '모바일',
#  '1CA10296': '기타',
#  'CRS25T950005M': '주방가전',
#  'SM-F721N7SEPMC': '모바일',
#  'NZ63B6507XH': '주방가전',
#  'RB34K60057F': '주방가전',
#  'P2022010046': '기타',
#  'GP-FGR175AMAYK': '모바일',
#  'HG55NT670UFXKR': '기타',
#  'V00068': '기타',
#  'EF-PG985TJEGKR': '모바일',
#  'EF-PG780TNEGKR': '모바일',
#  'SF247005': '기타',
#  'AW05B5171WWAZ1': '생활가전',
#  'JBLBOOMBOXBLKAS': '오디오',
#  'V00109': '기타',
#  'NT950QED-KT72D': 'PC/주변기기',
#  'SF230693': '기타',
#  'EF-PF926TGEGKR': '모바일',
#  '1FA10045': '기타',
#  'V00228': '기타',
#  'V00082': '기타',
#  'EF-VF711LGEGKR': '모바일',
#  'GP-R815BREECAC': '모바일',
#  'A0011': '기타',
#  'WF16T6000KW': '생활가전',
#  'GP-XVR500BRABW': '모바일',
#  'F301772': '기타',
#  'EF-GN980CBEGKR': '모바일',
#  'AKGN25BLK': '오디오',
#  'GP-FPF700HIBYK': '모바일',
#  'S-K-HBASKET2L': '주방가전',
#  'SM-F926NZGAKOO': '모바일',
#  'RZ24A5600AP': '주방가전',
#  'RB30R3503AP': '주방가전',
#  'VR30T85513W': '생활가전',
#  'RZ24A5660AP': '주방가전',
#  'EF-DT630UBKGKR': '모바일',
#  'DV19T8745BET': '생활가전',
#  'AW05A5171GZAS1': '생활가전',
#  'VS20R9074S3CW': '생활가전',
#  'p2022010056': '기타',
#  'KQ65LSB01BFXKR': 'TV',
#  '710': '기타',
#  'RA-F17DBB17': '주방가전',
#  'ROUNDDISH15SEASALT': '기타',
#  'MC32B7388CE': '주방가전',
#  'SI-GFUC40B1A2D': '생활가전',
#  'RP13T1011S9': '주방가전',
#  'V00317': '기타',
#  'EF-RS906CVEGKR': '모바일',
#  'EO-BG920BFKG': '오디오',
#  'SM-F711NZUYKOO': '모바일',
#  'WF21A9400KW': '생활가전',
#  'MG23A5378CU': '주방가전',
#  'OTG21110020': '기타',
#  'RF85B911155': '주방가전',
#  'NT950XDC-XD72E': 'PC/주변기기',
#  'V00196': '기타',
#  '2104481': '기타',
#  'p2022010005': '기타',
#  'NT950QDB-KD7SN': 'PC/주변기기',
#  '549': '기타',
#  'SM-T865NZNNKOO': '모바일',
#  'SM-R177NZKAPMF': '모바일',
#  'DV90TA040KE': '생활가전',
#  'SF254961': '기타',
#  'SM-A315NZKAKOO': '모바일',
#  'JBLGO3GRY': '오디오',
#  'AP110BSPPBH1S': '생활가전',
#  'a0024': '기타',
#  'RA-B23DBB39': '주방가전',
#  'EASYSET': '기타',
#  'sf232451': '기타',
#  'NT950XDB-KD71P': 'PC/주변기기',
#  'MLT-R204': 'PC/주변기기',
#  'CLT-P406C': 'PC/주변기기',
#  'KQ50QT67A-W': 'TV',
#  '2141345': '기타',
#  'SM-T510NZSEKOO': '모바일',
#  'GP-FPU022HOERK': '모바일',
#  'P00000SS': '기타',
#  'GP-FPR180AMDEK': '모바일',
#  'V00231': '기타',
#  'GP-FPR180HIBKK': '모바일',
#  'AW05B5171GWAT': '생활가전',
#  'DMS002': 'PC/주변기기',
#  'RF60A91D135': '주방가전',
#  'ECOVERZERO3R': '기타',
#  '2143764': '기타',
#  '842': '기타',
#  'SF237895': '기타',
#  'AF17TX773BZERT': '생활가전',
#  'SL-M2035W': 'PC/주변기기',
#  'VMM007': '기타',
#  'EF-OA135TPEGKR': '모바일',
#  '2144488': '기타',
#  '8801448365148': '기타',
#  'EF-ZG980CWEGKR': '모바일',
#  '122': '기타',
#  'CFX-H8YA0D': '생활가전',
#  'NT750XDA-XD7MU': 'PC/주변기기',
#  'RF85T9141T1': '주방가전',
#  'SF245106': '기타',
#  'SM-F711NZEWKOO': '모바일',
#  'SM-T510NZKEKOO': '모바일',
#  'MD-WATCHSTHA': '모바일',
#  'V00187': '기타',
#  'MT428D21K': 'smartthings',
#  'RF85B9001W6': '주방가전',
#  'DW60A8355LWS': '주방가전',
#  'DMS0013': 'PC/주변기기',
#  'DW60B8155TES': '주방가전',
#  'GP-TOU021HICWK': '모바일',
#  'GP-FPA426KDABK': '모바일',
#  'GP-FGR180KKATK': '모바일',
#  'F301780': '기타',
#  'RA-F17PURBT': '주방가전',
#  'SAM0011': '기타',
#  'CFX-H170DF1': '생활가전',
#  'DW60B5095TCUS': '주방가전',
#  'SM-R900NZAAK03': '모바일',
#  'SM-F711NLVEKOO': '모바일',
#  'RQ34A7815AP': '주방가전',
#  'SM-R835FSDAKTO': '모바일',
#  'KQ85QNA800FXKR': 'TV',
#  'EP-L4020NBKGKR': '모바일',
#  'MUVC-1F7210349': '모바일',
#  'GP-TYR905HCABK': '모바일',
#  'CLT-P407C': 'PC/주변기기',
#  'ROUNDDISH15FIG': '기타',
#  'KQ75QT89A-W': 'TV',
#  'ET-SFR86SUEGKR': '모바일',
#  'SM-F936NZEAKOO': '모바일',
#  'SL-T2273FW': 'PC/주변기기',
#  'A0031': '기타',
#  'CLT-Y405S': 'PC/주변기기',
#  'SM-F926NZKEKOO': '모바일',
#  'EJ-B3400UBKGKR': '모바일',
#  'RF85T926188': '주방가전',
#  'SAM20220915021': '기타',
#  'EF-VG998LAEGKR': '모바일',
#  'IE0476': '기타',
#  'INK-C160': 'PC/주변기기',
#  'sam0013': '기타',
#  'YEOSU-001': '기타',
#  'KU65UA7000FXKR': 'TV',
#  'SF238877': '기타',
#  'GP-R170HITODKD': '모바일',
#  'EF-ZG996CBEGKR': '모바일',
#  'V00229': '기타',
#  '066': '기타',
#  'KU60UA8000FXKR': 'TV',
#  'EF-ZG988CBEGKR': '모바일',
#  'WA16T6390BV': '생활가전',
#  'P2022060331': '기타',
#  'V00018': '기타',
#  'RA-K27BBB04': '주방가전',
#  'KQ50QA80-W1': 'TV',
#  'AF-C3T1D': '생활가전',
#  'SM-R920NZKDKOO': '모바일',
#  'P2022060305': '기타',
#  'AW05B5171WWAT3': '생활가전',
#  'KQ65QNB85-W15': 'TV',
#  'SP-P7-RADILS': 'TV',
#  'M': '기타',
#  'VS20T92P8SF': '생활가전',
#  'SM-F711N4RWKOO': '모바일',
#  'GP-TYR925HCASK': '모바일',
#  'RF85B97A1APN': '주방가전',
#  '3125014': '기타',
#  'SM-T725NZSDKOO': '모바일',
#  'GP-TOR190HOFWK': '모바일',
#  'MUVC-1F7110252': '모바일',
#  'ET-SFR87LSEGKR': '모바일',
#  'RA-K27BMM32': '주방가전',
#  'V00111': '기타',
#  'F301787': '기타',
#  'SM-T295NZKNKOO': '모바일',
#  'SM-G991NZIEKOO': '모바일',
#  'RZ24A58G0APB': '주방가전',
#  'NT930QED-KU71G': 'PC/주변기기',
#  'sam20220915022': '기타',
#  '132573-0001': '기타',
#  'KQ65QB65AFXKR': 'TV',
#  'AKGN700NCM2BTBLK': '오디오',
#  'ET-SFR86SPEGKR': '모바일',
#  'sf249219': '기타',
#  'SF237650': '기타',
#  'EP-DX310JWKGKR': '모바일',
#  'RA-F18BUUT1': '주방가전',
#  'SI-GFTQ40B1A1D': '생활가전',
#  'SM-G781NZWAKOO': '모바일',
#  'RA-K27DMM18': '주방가전',
#  'NT750XDA-XD7DS': 'PC/주변기기',
#  'OTG23010054': '기타',
#  'CFX-D140D': '생활가전',
#  'SM-A528NZKAKOO': '모바일',
#  'DV-FH18H': '생활가전',
#  'p2022010007': '기타',
#  'EF-NS906PBEGKR': '모바일',
#  '31': '기타',
#  'JBLGO2BLK': '오디오',
#  'MC35A8088CE': '주방가전',
#  'SFN-R35DXBG': '생활가전',
#  'p2022010017': '기타',
#  'F0040': '기타',
#  'EF-QG996TTEGKR': '모바일',
#  'RA-B23BBB18': '주방가전',
#  'LH55WMRWBGCXKR': 'PC/주변기기',
#  'ACM-B1M1SC': '생활가전',
#  'DV20B9760CB': '생활가전',
#  'EP-DA705BBKGKR': '모바일',
#  'P10111147': '기타',
#  'EF-KG985CLEGKR': '모바일',
#  'GP-JPU021LMDBK': '모바일',
#  'V00039': '기타',
#  'HGFG0037': '기타',
#  'MO22A7797CWR': '주방가전',
#  'EF-XN985FJEGKR': '모바일',
#  'DW60B5095TES': '주방가전',
#  'SM-X800NZAFKOO': '모바일',
#  'sf222079': '기타',
#  'VR50T95935P': '생활가전',
#  'RS84T5071M9': '주방가전',
#  'RA-K27TBB31': '주방가전',
#  'sf219812': '기타',
#  'RF85A9103APYW': '주방가전',
#  'SL-T1677DW': 'PC/주변기기',
#  'SM-R180NZNAKOO': '모바일',
#  'EP-N5200TWKGKR': '모바일',
#  '501': '기타',
#  'A0022': '기타',
#  '270': '기타',
#  'NT950XEE-XU72S': 'PC/주변기기',
#  'G92290018': '기타',
#  'V00256': '기타',
#  'SM-S908NZKRKOO': '모바일',
#  'ECOVERALL2': '기타',
#  'MC35A8599LF': '주방가전',
#  'NT950XDB-KH59S': 'PC/주변기기',
#  'OBD0003': '기타',
#  'EF-BT870PNEGKR': '모바일',
#  'SSI-X010AWT': '기타',
#  'f0006': '기타',
#  '828': '기타',
#  'SM-R170NZSAKOO': '모바일',
#  'SM-T736NLGEKOO': '모바일',
#  'NZ9899RB60PW': '주방가전',
#  'SF231040': '기타',
#  'RF85A92V1AP': '주방가전',
#  'V00070': '기타',
#  'RZ24T5660APW': '주방가전',
#  'DW60B5095LWUS': '주방가전',
#  'SM-A528NZKBKOO': '모바일',
#  'EF-KG996CVEGKR': '모바일',
#  'RA-K27TBB05': '주방가전',
#  'A0027': '기타',
#  'SM-R865NZSAKOO': '모바일',
#  'RT50T6035WW': '주방가전',
#  'p2022060333': '기타',
#  'F400921': '기타',
#  'WF24DV19GGL': '생활가전',
#  'SM-R510NZAAGS2': '모바일',
#  'GP-TYR870SAABK': '모바일',
#  'RQ33T74A232': '주방가전',
#  'SM-T733NLIAKOO': '모바일',
#  'RA-F17BUU39': '주방가전',
#  'KQ55QNB85-W1': 'TV',
#  'RA-F17BUU93': '주방가전',
#  'SKK-ATE': '생활가전',
#  'P00000ZY': '기타',
#  'EF-BX900PBEGKR': '모바일',
#  'AJ200RS3PBC5SY': '생활가전',
#  'soul8': '기타',
#  'AX34A5310WWD': '생활가전',
#  'JBLT760NCBLS': '오디오',
#  'RA-K23DAA32': '주방가전',
#  'SM-N981NZAEKOO': '모바일',
#  'MLT-D105L': 'PC/주변기기',
#  'NT950XDC-XD71R': 'PC/주변기기',
#  'SRP-9500W': 'PC/주변기기',
#  'p2022060366': '기타',
#  'EF-EA716PWEGKR': '모바일',
#  'IE0225': '기타',
#  'AR11B9150HZS': '생활가전',
#  'SM-R875NZSAPMS': '모바일',
#  'DODRAM10501': '기타',
#  'A0018': '기타',
#  'RA-F18DBBGLLD9': '주방가전',
#  'RH81R6010S8': '주방가전',
#  'AX90T9420WPD': '생활가전',
#  'SM-A325NZWAKOO': '모바일',
#  'RT62N704HS9': '주방가전',
#  'EF-KG991CVEGKR': '모바일',
#  'CRS25T850006M': '주방가전',
#  'KQ65LSA03-WT': 'TV',
#  'AX106A9911EDZ1': '생활가전',
#  'P0000BAC': '기타',
#  'SM-F700NZKAKOO': '모바일',
#  'RA-K31DMM39': '주방가전',
#  'V00143': '기타',
#  'DV20A9740CE': '생활가전',
#  'DW60T7045FS': '주방가전',
#  '1CA10051': '기타',
#  '375': '기타',
#  'DODRAM10487': '기타',
#  'ET-SFR90SZEGKR': '모바일',
#  'KU43UB8000-W1': 'TV',
#  'AP110BSPPBH8S': '생활가전',
#  'DV16T8740BVS': '생활가전',
#  'JBLQUAN-D-ST-350': '오디오',
#  'EO-IC100BBEGKR': '오디오',
#  '662': '기타',
#  'EF-ZG985CBEGKR': '모바일',
#  'EF-EA336PBEGKR': '모바일',
#  '2143726': '기타',
#  'DV20B9760CP': '생활가전',
#  'sf252439': '기타',
#  'JBLT500BTBLK': '오디오',
#  'RA-K23DAA35': '주방가전',
#  'CFX-D100D': '생활가전',
#  'SM-S908NZGWKOO': '모바일',
#  'RR39T7605APBE': '주방가전',
#  'V00147': '기타',
#  'P0000CPX': '기타',
#  'EF-RS908CNEGKR': '모바일',
#  'EF-PN975TLEGKR': '모바일',
#  '1FA10068': '기타',
#  'X00003713': '기타',
#  'OTTA0007': '기타',
#  'CLT-Y506S': 'PC/주변기기',
#  'MUVC-1F7110051': '모바일',
#  '562': '기타',
#  'VS20R9043QACS': '생활가전',
#  'EF-OA135TLEGKR': '모바일',
#  '429': '기타',
#  'CLT-R407': 'PC/주변기기',
#  'KU55UT7000-S': 'TV',
#  'AP130BSPPHH1S': '생활가전',
#  'sf234259': '기타',
#  'CFX-H8XA0D': '생활가전',
#  'DW60A8575LYUS': '주방가전',
#  'RA-B23BBB39': '주방가전',
#  'sam0010': '기타',
#  'MLT-D105S': 'PC/주변기기',
#  'RA-K27PUU02': '주방가전',
#  'V00258': '기타',
#  '582': '기타',
#  'V00090': '기타',
#  'V00261': '기타',
#  '1301428': '기타',
#  'KQ50QA60AFXKR': 'TV',
#  'VS15R8500BF': '생활가전',
#  'NT550XCJ-KF34W': 'PC/주변기기',
#  'V00208': '기타',
#  'F0032': '기타',
#  'VG-SOCN15/KR': 'TV',
#  'RQ34A7815AP01': '주방가전',
#  'MUVC-1F7210386': '모바일',
#  'AP110BSPDBC1S': '생활가전',
#  'KQ50QB65-W1': 'TV',
#  'AF18AX978VZRS': '생활가전',
#  'EF-QA125TTEGKR': '모바일',
#  'VS20B957F5U': '생활가전',
#  'V00356': '기타',
#  'GP-TOU020SABWK': '모바일',
#  'V00262': '기타',
#  '674': '기타',
#  'WF21DV17VVLF5K': '생활가전',
#  'P2022010019': '기타',
#  'CRT-RPK0640I': '기타',
#  'RWP71210AARA': '주방가전',
#  'V00328': '기타',
#  'VS20A957G3B': '생활가전',
#  'SM-R830NZSAKOO': '모바일',
#  'RA-F17DUU05': '주방가전',
#  'HW-Q900A-95': '오디오',
#  'GP-FPF936AMAEK': '모바일',
#  'RA-M17DAA44': '주방가전',
#  'p2022010012': '기타',
#  'GP-TOT530HIAGK': '모바일',
#  'EP-TA20KWKUG': '모바일',
#  'JBLCHARGE5RED': '오디오',
#  'f0021': '기타',
#  'AF-C3Y1D': '생활가전',
#  'ET-SLR85SAEGKR': '모바일',
#  'DW50T4065FS': '주방가전',
#  'AC110BS4PHH1SY': '생활가전',
#  '1CA10057': '기타',
#  'WF21B6200KV7L': '생활가전',
#  'AF17TX773FZRZ': '생활가전',
#  'JBLBAR51IMBLKAS': '오디오',
#  'RQ33T7103S9': '주방가전',
#  'A0046': '기타',
#  'LS32BM80BUKXKR': 'PC/주변기기',
#  'OTG23010106': '기타',
#  'JBLENDURPEAKBLK': '오디오',
#  'SF231035': '기타',
#  'CRS25T950005C': '주방가전',
#  'SF254465': '기타',
#  '712': '기타',
#  'EJ-PS908BBEGKR': '모바일',
#  'p2022010020': '기타',
#  'LS27BM503EKXKR': 'PC/주변기기',
#  'GP-TOT530HIABK': '모바일',
#  '843': '기타',
#  'RQ48R9421T1': '주방가전',
#  '729': '기타',
#  '1CA10298': '기타',
#  'F301782': '기타',
#  'EP-P4300TBKGKR': '모바일',
#  'EF-RG998CJEGKR': '모바일',
#  'RZ32T7605AP': '주방가전',
#  'P10131062': '기타',
#  'RA-B23DBB31': '주방가전',
#  'CLT-C504S': 'PC/주변기기',
#  'ET-SLR85SBEGKR': '모바일',
#  '663': '기타',
#  'AP130BSPPBH1S': '생활가전',
#  'P2022010049': '기타',
#  'SOUL25': '기타',
#  'GP-G970AMEFAKA': '모바일',
#  'AR06A1171HZS': '생활가전',
#  'SM-R865NZKAPMS': '모바일',
#  'SM-R190NZVAK01': '모바일',
#  'NZ63A8858XV': '주방가전',
#  'RA-F17DUU32': '주방가전',
#  'EF-PF711TMEGKR': '모바일',
#  '101000021': '기타',
#  'AW05B5171BWAZ3': '생활가전',
#  'RT25NARAHS8': '주방가전',
#  'SM-S906NZWWKOO': '모바일',
#  'CLT-M404S': 'PC/주변기기',
#  '136': '기타',
#  'AX106A9911EDT1': '생활가전',
#  'CY-TF65BRCXKR': '기타',
#  'SM-R510NZAAKON': '모바일',
#  'RP22A31A1Z1': '주방가전',
#  'soul13': '기타',
#  'WF23T9500KE': '생활가전',
#  'DW60B5095LB': '주방가전',
#  'DV20B9760CF': '생활가전',
#  'RQ32B76A5AP05': '주방가전',
#  'RA-M17PAA05': '주방가전',
#  'RA-F17DUU3G': '주방가전',
#  'SM-A135NZWEKOO': '모바일',
#  'MUVC-9G9960022': '모바일',
#  'VG-SOCR15/KR': 'TV',
#  'MUVC-1F7210384': '모바일',
#  'SF254466': '기타',
#  'SM-F711N1FFKOO': '모바일',
#  '266': '기타',
#  '8808244100973-1': '기타',
#  'DF10T9301KG-AS': '생활가전',
#  'RF85T9331T1': '주방가전',
#  'PCM-NF15W': '기타',
#  '2112526': '기타',
#  'SI-GP200-XS': '생활가전',
#  'SM-T875NDBBFML': '모바일',
#  'DW60A8355TES': '주방가전',
#  '106': '기타',
#  'RF85A9103AP': '주방가전',
#  'EF-PA536TLEGKR': '모바일',
#  'SM-F711N1VWKOO': '모바일',
#  'JBLQUANTUM100BLK': '오디오',
#  'GP-TYR890AMFWK': '모바일',
#  'RA-F18PUU02': '주방가전',
#  'SM-R177NLVAPMF': '모바일',
#  'AF17B6474WST': '생활가전',
#  'KQ55LST01E-AS2': 'TV',
#  'RS84T5041M9': '주방가전',
#  'EF-NN980PBEGKR': '모바일',
#  'A0010': '기타',
#  '003': '기타',
#  'KQ65QA67AFXKR': 'TV',
#  'HGFG0013': '기타',
#  'NT950QDB-KD72L': 'PC/주변기기',
#  'EF-NN985PSEGKR': '모바일',
#  'VS15R8548S5CD': '생활가전',
#  'p2022060327': '기타',
#  'HX-MK10P14': 'PC/주변기기',
#  'MLT-D203L': 'PC/주변기기',
#  'DW60A8575TEUT': '주방가전',
#  'mzache-stick-500g-2': '기타',
#  'RT16BG': '주방가전',
#  'EF-ZG99PCBEGKR': '모바일',
#  '102137': '기타',
#  'LS24AG320NKXKR': 'PC/주변기기',
#  'KU55UB8000FXKR': 'TV',
#  'DV16T8740SER': '생활가전',
#  '802': '기타',
#  'V00007': '기타',
#  'V3P03': 'smartthings',
#  'RA-R23BAA18': '주방가전',
#  'KU58UA7000-W1': 'TV',
#  'VG-SCLB00YS/KR': 'TV',
#  '703': '기타',
#  'RF85T9132APW': '주방가전',
#  'LH50BEAHLBFXKR': 'PC/주변기기',
#  'sf222076': '기타',
#  'GP-XVR510BJAJK': '모바일',
#  'NZ31T3703PK': '주방가전',
#  '211': '기타',
#  'p2022010008': '기타',
#  'VR30T80313P': '생활가전',
#  'RP20T31A1G2': '주방가전',
#  'KQ43QA60AFXKR': 'TV',
#  'ET-SFR50MLEGKR': '모바일',
#  'AF17A6478WZZ': '생활가전',
#  'G94120012': '기타',
#  'GF000005': '기타',
#  'VG-FSD3BW/KR': 'TV',
#  'IE0485': '기타',
#  'MD-S10EGOOLYD': '모바일',
#  'EF-PF721TGEGKR': '모바일',
#  'sf254500': '기타',
#  'GP-XVR510BJCBK': '모바일',
#  'D85411': '기타',
#  'a0034': '기타',
#  'CFX-H8XB0D': '생활가전',
#  'RF85B91F1W6': '주방가전',
#  'RR39T7685APP': '주방가전',
#  '2112126': '기타',
#  'JBLT125TWSBLKAS': '오디오',
#  'P10101082': '기타',
#  'SPA-JC31CCB': 'PC/주변기기',
#  'P2022010054': '기타',
#  'WA19A8370KV': '생활가전',
#  '521': '기타',
#  'SM-R865NZDAKOO': '모바일',
#  'NT950QDB-KD7MG': 'PC/주변기기',
#  'VFP018': '기타',
#  'AX94T9360WWD': '생활가전',
#  'GP-FPR177AMAGK': '모바일',
#  'JBLPB710-REFMINI': '오디오',
#  'GP-TYR820HIBBK': '모바일',
#  'RA-F18BUU32': '주방가전',
#  'DV17T8520BW': '생활가전',
#  'NT930XDB-KC58P': 'PC/주변기기',
#  'RA-K15DUU93': '주방가전',
#  'SFN-R23DXNV': '생활가전',
#  '1FA10116': '기타',
#  'JBLCLUB700BTBLK': '오디오',
#  'VFF033': '기타',
#  'SM-R870NZKACLB': '모바일',
#  'EP-TA12KWKUG': '모바일',
#  'KQ75QNA90A-W6': 'TV',
#  'VS20B956AXE50G': '생활가전',
#  'KQ75QNB85-5': 'TV',
#  'EF-NS906PJEGKR': '모바일',
#  'P00000ZA': '기타',
#  'SF251684': '기타',
#  'DODRAM10489': '기타',
#  'MR-104402': '기타',
#  'P00000ZP': '기타',
#  'KQ55QA60-W1': 'TV',
#  'AF17A7972RFRT': '생활가전',
#  'V00233': '기타',
#  'RF85T9131AP': '주방가전',
#  'V00200': '기타',
#  'soul22': '기타',
#  'EJ-PT860BJEGKR': '모바일',
#  'EP-T1510XBKGKR': '모바일',
#  'RZ34A7965APB': '주방가전',
#  'RA-K27DUU3B': '주방가전',
#  'V00073': '기타',
#  'sam20220221006': '기타',
#  'sam20220915012': '기타',
#  '1301431': '기타',
#  'F0026': '기타',
#  'RA-K27DBB01': '주방가전',
#  'SI-GFTV50B1A1D': '생활가전',
#  '1CA10015': '기타',
#  'F0024': '기타',
#  'V00230': '기타',
#  'SM-R870NZGDPMC': '모바일',
#  'soul35': '기타',
#  'SM-R175NZBAKOO': '모바일',
#  'DB400SDA-YB242': 'PC/주변기기',
#  'IE0501': '기타',
#  'DV16T8740SE': '생활가전',
#  'MUVC-1F7210348': '모바일',
#  'a0036': '기타',
#  'SM-F711NZEFKOO': '모바일',
#  'RF85T926155': '주방가전',
#  'SOUL17': '기타',
#  'RA-R23DAA17': '주방가전',
#  'VS20T92P7SF': '생활가전',
#  'GF300047': '기타',
#  'SM-R870NZKAKOD': '모바일',
#  '458': '기타',
#  'SF233519': '기타',
#  'GP-G970HIFGHKB': '모바일',
#  'EJ-PT870BJEGKR': '모바일',
#  'SM-R890NZSDK02': '모바일',
#  '180': '기타',
#  'DW60A8575LW': '주방가전',
#  'MC28M6036CW': '주방가전',
#  'RZ24A58E0AP': '주방가전',
#  '155': '기타',
#  'SAM20220915037': '기타',
#  'SM-R177NZKAK04': '모바일',
#  'P10991126': '기타',
#  'WF25D20BPPL': '생활가전',
#  'RA-R23DAA48': '주방가전',
#  'RA-F17DUU93': '주방가전',
#  'P0000COS': '기타',
#  'RA-K27BMM07': '주방가전',
#  'WF14F5K3AVW1': '생활가전',
#  'RF85B9121APW': '주방가전',
#  'AF-A2T1D': '생활가전',
#  'AF18AX777EFRT': '생활가전',
#  'GP-TOR905SAAPK': '모바일',
#  'LS32BM80PUKXKR': 'PC/주변기기',
#  '020': '기타',
#  'MUVC-9G9980034': '모바일',
#  'RA-K27NMM39': '주방가전',
#  'V00270': '기타',
#  'NT950QCG-X71SC': 'PC/주변기기',
#  'AR09B5150HZS': '생활가전',
#  'G12391134': '기타',
#  'RA-F18DUU06': '주방가전',
#  'sf254469': '기타',
#  'F0012': '기타',
#  ...}

# %%
#데이터셋 만들기
dataset = []    # 데이터셋 구조 [ [a,b], [a,c], [a,b,c] .... ]

for i in range(len(df)) :
    sku = df['Model Code (v41)'][i]
    revised = sku.split(",")
    code = []
    for j in range(len(revised)) :
        code.append(dic_category[revised[j]])   #각 SKU 리스트에 담기
    
    for k in range(df['Order (purchase event)'][i]) :   #order 수만큼 담기
        dataset.append(code)

# %% [markdown]
# ### 1) 기타 제거

# %%
 #기타제거
ho = []
rm_set = {'기타'}
for s in dataset:
    arr_new = [i for i in s if i not in rm_set]
    ho.append(arr_new) # [5, 7, 2, 7]
dataset=ho

print('기타 제거 후, 행 수: ',len(dataset))
# Out:
# 원래 행 수:  199894
# 기타 제거 후, 행 수:  199894

# %%
#장바구니 분석
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset) #True / False
df2 = pd.DataFrame(te_ary, columns=te.columns_)
itemsets_data = apriori(df2, min_support=0.00001, use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
#rules = association_rules(itemsets_data, metric='confidence', min_threshold=1).sort_values('confidence',ascending=False).reset_index(drop=True)
itemsets_data['count']=(itemsets_data['support']	*len(dataset)).astype(int)
itemsets_data.to_csv(f'{path}\\{file_name}\\{x.month}월_한총 분석결과파일 1depth.csv', encoding = 'utf-8-sig')
itemsets_data
# Out:
#      support                   itemsets   count
# 0   0.732761                      (모바일)  149555
# 1   0.097801                     (생활가전)   19961
# 2   0.066135                  (PC/주변기기)   13498
# 3   0.064939                       (기타)   13254
# 4   0.033508                     (주방가전)    6839
# 5   0.017070                      (오디오)    3483
# 6   0.015576                       (TV)    3179
# 7   0.014385               (주방가전, 생활가전)    2936
# 8   0.008486              (smartthings)    1732
# 9   0.005238                 (모바일, 오디오)    1069
# 10  0.004880                 (생활가전, TV)     996
# 11  0.004243                 (주방가전, TV)     866
# 12  0.002273           (주방가전, 생활가전, TV)     464
# 13  0.001401             (PC/주변기기, 모바일)     286
# 14  0.001298                (모바일, 생활가전)     265
# 15  0.001259                  (모바일, 기타)     257
# 16  0.001200                 (생활가전, 기타)     245
# 17  0.000951            (PC/주변기기, 생활가전)     194
# 18  0.000647              (PC/주변기기, TV)     132
# 19  0.000500                  (오디오, TV)     102
# 20  0.000475                (생활가전, 오디오)      97
# 21  0.000426                   (기타, TV)      87
# 22  0.000392            (PC/주변기기, 주방가전)      80
# 23  0.000304                (주방가전, 오디오)      62
# 24  0.000260             (PC/주변기기, 오디오)      53
# 25  0.000260                (주방가전, 모바일)      53
# 26  0.000220         (모바일, smartthings)      45
# 27  0.000216                  (모바일, TV)      44
# 28  0.000176                  (기타, 오디오)      36
# 29  0.000167              (PC/주변기기, 기타)      34
# 30  0.000157                 (주방가전, 기타)      31
# 31  0.000137      (주방가전, PC/주변기기, 생활가전)      28
# 32  0.000113          (주방가전, 생활가전, 오디오)      23
# 33  0.000088          (smartthings, TV)      18
# 34  0.000083            (생활가전, 오디오, TV)      17
# 35  0.000083        (생활가전, smartthings)      17
# 36  0.000083        (PC/주변기기, 주방가전, TV)      17
# 37  0.000083            (주방가전, 오디오, TV)      17
# 38  0.000073        (PC/주변기기, 생활가전, TV)      15
# 39  0.000064        (주방가전, smartthings)      13
# 40  0.000059          (주방가전, 모바일, 생활가전)      12
# 41  0.000054      (주방가전, 생활가전, 오디오, TV)      11
# 42  0.000054           (주방가전, 생활가전, 기타)      11
# 43  0.000044         (smartthings, 오디오)       9
# 44  0.000039  (주방가전, PC/주변기기, 생활가전, TV)       7
# 45  0.000029            (모바일, 생활가전, TV)       6
# 46  0.000029          (기타, smartthings)       6
# 47  0.000024             (주방가전, 기타, TV)       5
# 48  0.000024             (모바일, 기타, 오디오)       5
# 49  0.000024            (주방가전, 모바일, TV)       5
# 50  0.000020            (모바일, 기타, 생활가전)       3
# 51  0.000020       (PC/주변기기, 모바일, 생활가전)       3
# 52  0.000020        (PC/주변기기, 모바일, 오디오)       3
# 53  0.000020      (주방가전, 모바일, 생활가전, TV)       3
# 54  0.000015           (모바일, 생활가전, 오디오)       3
# 55  0.000015       (주방가전, 생활가전, 기타, TV)       3
# 56  0.000015             (생활가전, 기타, TV)       3

# %%
'''   association_rules을 진행한다면 하기 

x = dt.datetime.now()

num_conq=1
N=4

def frozen_convert(sets) : 
    return [list(sets)]

for num_ant in [1,2,3]:
    df = rules[rules.apply(lambda x:True if len(x.antecedents) == int(num_ant) else False, axis=1) & rules.apply(lambda x:True if len(x.consequents) == int(num_conq) else False, axis=1)]
    df = df.sort_values('confidence', ascending=False)
    df = df.round(N)
    df[['antecedents','consequents']] =df[['antecedents','consequents']].applymap(lambda x: frozen_convert(x))
    df['antecedents']=df['antecedents'].astype(str).apply(lambda x: x.replace('[[','['))
    df['antecedents']=df['antecedents'].apply(lambda x: x.replace(']]',']'))
    df['consequents']=df['consequents'].astype(str).apply(lambda x: x.replace('[[','['))
    df['consequents']=df['consequents'].apply(lambda x: x.replace(']]',']'))
    df.to_csv(f'{path}\\{file_name}\\{x.month}월_한총 분석결과파일_{num_ant}.csv', encoding = 'utf-8-sig')

'''
